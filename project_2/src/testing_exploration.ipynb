# %%
from exploration import Exploration

# %%
optimizers = ["Constant", "Momentum", "Adam"]#, "Adagrad_Momentum", "RMSprop", "Adagrad"]
layer_sizes = [4,8]
num_hidden_layers = [2,3]
learning_rates = [0.1, 0.01]
batch_sizes = [3000, 5000]
activation_functions = ["ReLU", "leaky_ReLU"]#, "sigmoid"]

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes, activation_functions)

# %%
exploration1.do_all()
# Out:
# 100%|██████████| 3/3 [00:03<00:00,  1.15s/it]
# Best optimizer: Adam
# Best structure: [2, 4, 4, 1]
# Best activation functions: ['leaky_ReLU', 'leaky_ReLU']
# Best learning rate and batch size: (0.01, 3000)
# Final accuracy: -0.1434112787246704

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes, activation_functions)

# %%
exploration2.generate_data()
exploration2.do_all()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# 100%|██████████| 3/3 [00:01<00:00,  1.97it/s]
# Best optimizer: Constant
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['ReLU', 'ReLU']
# Best learning rate and batch size: (0.1, 3000)
# Final accuracy: -9.84798812866211
