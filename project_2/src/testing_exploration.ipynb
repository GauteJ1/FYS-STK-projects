# %%
from exploration import Exploration
# Out:
# Bad value in file '../plot_settings.mplstyle', line 32 ("axes.prop_cycle: plt.cycler('color', plt.get_cmap('tab20').colors)"): Key axes.prop_cycle: "plt.cycler('color', plt.get_cmap('tab20').colors)" is not a valid cycler construction: name 'plt' is not defined

# %%
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "RMSprop"]
layer_sizes = [8,16]
num_hidden_layers = [2, 3]
learning_rates = [0.01, 0.001, 0.0001]
batch_sizes_cont = [1000,3000, 5000]
batch_sizes_disc = [100,200, 300]
activation_functions = ["ReLU","sigmoid","leaky_ReLU"]

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
exploration1.do_all(print_into=True)
# Out:
# Best optimizer (gives the highest $R^2$): Momentum
# 100%|██████████| 2/2 [00:20<00:00, 10.32s/it]
# Best structure (gives the highest $R^2$): [2, 8, 8, 1]
# Best activation functions (gives the highest $R^2$): ['ReLU', 'ReLU', 'identity']
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1033bcf50>>
# Traceback (most recent call last):
#   File "/Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
exploration2.do_all(print_into=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Best optimizer (gives the highest Accuracy): Adam
# 100%|██████████| 2/2 [00:29<00:00, 14.69s/it]
# Best structure (gives the highest Accuracy): [30, 16, 8, 1]
# Best activation functions (gives the highest Accuracy): ['sigmoid', 'ReLU', 'sigmoid']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
# ----> 2 exploration2.do_all(print_into=True)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:534, in Exploration.do_all(self, print_into)
#     532 self.find_structure()
#     533 self.find_activation_functions()
# --> 534 self.grid_search_for_optimizer()
#     535 self.make_best()
#     536 self.plot_best()
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:384, in Exploration.grid_search_for_optimizer(self)
#     381 all_loss = {}
#     383 for optim in self.top_3_optimizers:
# --> 384     test_accuracy, test_loss = self.grid_search_lr_batch(optimizer=optim)
#     385     all_acc[optim] = test_accuracy
#     386     all_loss[optim] = test_loss
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:361, in Exploration.grid_search_lr_batch(self, optimizer)
#     358 for batch_size in self.batch_sizes:
#     359     model = NeuralNetwork(self.best_structure, self.best_activation_functions,
#     360                         self.cost_function, self.type_model, optimizer)
# --> 361     model.train_network(self.inputs, self.targets, epochs=self.intermediary_epochs,
#     362                         learning_rate=lr, batch_size=batch_size)
#     363     lr_losses.append(model.test_loss)
#     364     lr_accuracies.append(model.test_accuracy)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:223, in NeuralNetwork.train_network(self, inputs, targets, epochs, learning_rate, batch_size)
#     220     batch_inputs = train_inputs
#     221     batch_targets = train_targets
# --> 223 layers_grad = self.gradient(batch_inputs, batch_targets)
#     225 theta = self.ravel_layers(self.layers)
#     226 theta_grad = self.ravel_layers(layers_grad)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:301, in NeuralNetwork.jaxgrad_gradient(self, inputs, targets)
#     298     predictions = jax_grad_predict(layers, inputs)
#     299     return self.cost_fun(predictions, targets)
# --> 301 gradients = grad(jax_grad_cost, argnums=0)(self.layers, inputs, targets)
#     303 return gradients
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:462, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     460   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     461 if not has_aux:
# --> 462   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     463 else:
#     464   ans, vjp_py, aux = _vjp(
#     465       f_partial, *dyn_args, has_aux=True)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:1962, in _vjp(fun, has_aux, *primals)
#    1960 if not has_aux:
#    1961   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1962   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    1963   out_tree = out_tree()
#    1964 else:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:142, in vjp(traceable, primals, has_aux)
#     140 def vjp(traceable, primals, has_aux=False):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:681, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     679 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     680   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 681   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     682   assert not env
#     683   del main, fun, env
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:299, in NeuralNetwork.jaxgrad_gradient.<locals>.jax_grad_cost(layers, inputs, targets)
#     294 def jax_grad_cost(
#     295     layers: list[float], inputs: np.ndarray, targets: np.ndarray
#     296 ) -> np.ndarray:
#     297     # Mimicing cost, but with layers as argument to use jax.grad on it
#     298     predictions = jax_grad_predict(layers, inputs)
# --> 299     return self.cost_fun(predictions, targets)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/methods.py:87, in binary_cross_entropy(predictions, targets)
#      84 epsilon = 1e-6
#      85 predictions = jnp.clip(predictions, epsilon, 1 - epsilon) # to avoid nan
# ---> 87 bce = -jnp.mean(targets * jnp.log(predictions) + (1 - targets) * jnp.log(1 - predictions))
#      89 if jnp.isnan(bce):
#      90     raise ValueError("NaN encountered in binary cross-entropy")
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1036, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1035 def op(self, *args):
# -> 1036   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:177, in ufunc.__call__(self, out, where, *args)
#     175   raise NotImplementedError(f"where argument of {self}")
#     176 call = self.__static_props['call'] or self._call_vectorized
# --> 177 return call(*args)
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/pjit.py:356, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     353 if config.no_tracing.value:
#     354   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     355                      "`jit`, but 'no_tracing' is set")
# --> 356 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     357     fun, jit_info, *args, **kwargs)
#     358 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     359 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/pjit.py:189, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     186   args_flat = [*init_states, *args_flat]
#     188 try:
# --> 189   out_flat = pjit_p.bind(*args_flat, **p.params)
#     190 except pxla.DeviceAssignmentMismatchError as e:
#     191   fails, = e.args
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:302, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     300   msg = f"Differentiation rule for '{primitive}' not implemented"
#     301   raise NotImplementedError(msg)
# --> 302 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     303 if primitive.multiple_results:
#     304   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/pjit.py:2085, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    2083 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    2084 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 2085 outputs = pjit_p.bind(
#    2086     *primals_in, *_filter_zeros_in(tangents_in),
#    2087     jaxpr=jaxpr_jvp,
#    2088     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    2089     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    2090     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    2091     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    2092     resource_env=resource_env,
#    2093     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    2094     name=name,
#    2095     keep_unused=keep_unused,
#    2096     inline=inline)
#    2098 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    2099 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/core.py:542, in Trace.full_raise(self, val)
#     540       return self.pure(val)
#     541   else:
# --> 542     return self.pure(val)
#     543 val._assert_live()
#     544 level = self.level
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:151, in JaxprTrace.pure(self, val)
#     150 def pure(self, val: Any) -> JaxprTracer:
# --> 151   return self.new_const(val)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:162, in JaxprTrace.new_const(self, val)
#     160 if isinstance(val, Tracer) and val._trace.level == self.level:
#     161   raise Exception
# --> 162 return JaxprTracer(self, PartialVal.known(val), None)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:122, in PartialVal.known(cls, const)
#     120 @classmethod
#     121 def known(cls, const: core.Value) -> PartialVal:
# --> 122   return PartialVal((None, const))
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:118, in PartialVal.__new__(cls, xs)
#     116   # invariant checks
#     117   assert (pv is None) ^ (const is None)
# --> 118 return tuple.__new__(cls, xs)
#
# KeyboardInterrupt:
