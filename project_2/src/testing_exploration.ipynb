# %%
from exploration import Exploration

# %%
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "RMSprop", "Adagrad"]
layer_sizes = [4,8,16]
num_hidden_layers = [2,3,4]
learning_rates = [0.1, 0.01,0.001]
batch_sizes_cont = [1000, 3000, 5000]
batch_sizes_disc = [100, 200, 300]
activation_functions = ["ReLU", "leaky_ReLU", "sigmoid"]

# %%
# smaller set of things to check for testing the code
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "RMSprop", "Adagrad"]
layer_sizes = [4,8]
num_hidden_layers = [2,4]
learning_rates = [0.01,0.001]
batch_sizes_cont = [1000, 5000]
batch_sizes_disc = [100, 300]
activation_functions = ["ReLU", "sigmoid"]

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
exploration2.do_all(print_into=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Best optimizer: Momentum
# for Constant: 5.5718841552734375
# for Momentum: 5.652446269989014
# for Adam: 5.170604228973389
# for Adagrad_Momentum: 5.412980079650879
# for RMSprop: 5.3322649002075195
# for Adagrad: 5.170527935028076
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['sigmoid', 'ReLU', 'sigmoid']
# 100%|██████████| 6/6 [00:13<00:00,  2.27s/it]
# Best optimizer: Constant
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['sigmoid', 'ReLU', 'sigmoid']
# Best learning rate and batch size: (0.01, 100)
# Final f1 socre: 0.18666666746139526

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
exploration1.do_all(print_into=True)
# Out:
# Best optimizer: Constant
# for Constant: 0.06574689596891403
# for Momentum: 0.06748250126838684
# for Adam: 0.12708435952663422
# for Adagrad_Momentum: 0.11237681657075882
# for RMSprop: 0.10696753114461899
# for Adagrad: 0.11871150135993958
# Best structure: [2, 4, 4, 1]
# Best activation functions: ['ReLU', 'ReLU', 'identity']
# 100%|██████████| 6/6 [00:07<00:00,  1.32s/it]
# Best optimizer: Momentum
# Best structure: [2, 4, 4, 1]
# Best activation functions: ['ReLU', 'ReLU', 'identity']
# Best learning rate and batch size: (0.01, 1000)
# Final r^2 score: 0.7983888983726501
