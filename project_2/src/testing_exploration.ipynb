# %%
from exploration import Exploration

# %%
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "Adagrad", "RMSprop"]
layer_sizes = [4,8,12]
num_hidden_layers = [2,3,4]
learning_rates = [0.1, 0.01, 0.001, 0.0001]
batch_sizes_cont = [1000,3000, 5000]
batch_sizes_disc = [100,200, 300]
activation_functions = ["ReLU","sigmoid","leaky_ReLU"]

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
exploration2.do_all(print_into=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Best optimizer: Adam
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['leaky_ReLU', 'sigmoid', 'sigmoid']
# 100%|██████████| 6/6 [00:13<00:00,  2.20s/it]
# Best optimizer: Adagrad_Momentum
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['leaky_ReLU', 'sigmoid', 'sigmoid']
# Best learning rate and batch size: (0.1, 200)
# Final recall: 0.9696969985961914

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
exploration1.do_all(print_into=True)
# Out:
# Best optimizer: Momentum
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
# ----> 2 exploration1.do_all(print_into=True)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:444, in Exploration.do_all(self, print_into)
#     442 self.generate_data()
#     443 self.find_ok_optimizer()
# --> 444 self.find_structure()
#     445 self.find_activation_functions()
#     446 self.grid_search_for_optimizer()
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:217, in Exploration.find_structure(self)
#     214 network_shape = [self.input_size] + list(sizes) + [self.output_size]
#     216 model = NeuralNetwork(network_shape, self.intermediary_activation_funcs, self.cost_function, "continuous", self.best_optimizer)
# --> 217 model.train_network(self.inputs, self.targets, epochs=self.intermediary_epochs, learning_rate=self.intermediary_lr, batch_size=self.intermediary_batch_size)
#     219 test_loss.append(model.test_loss)
#     220 test_accuracy.append(model.test_accuracy)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:212, in NeuralNetwork.train_network(self, inputs, targets, epochs, learning_rate, batch_size)
#     209     np.random.shuffle(random_idx)
#     210     random_idx = random_idx[:batch_size]
# --> 212     batch_inputs = train_inputs[random_idx]
#     213     batch_targets = train_targets[random_idx]
#     214 else:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/array.py:366, in ArrayImpl.__getitem__(self, idx)
#     361       out = lax.squeeze(out, dimensions=dims)
#     363     return ArrayImpl(
#     364         out.aval, sharding, [out], committed=False, _skip_checks=True)
# --> 366 return lax_numpy._rewriting_take(self, idx)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:10622, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#   10619       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#   10621 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# > 10622 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#   10623                unique_indices, mode, fill_value)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:10631, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#   10628 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#   10629             unique_indices, mode, fill_value):
#   10630   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# > 10631   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#   10632   y = arr
#   10634   if fill_value is not None:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:10775, in _index_to_gather(x_shape, idx, normalize_indices)
#   10772   if normalize_indices:
#   10773     advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#   10774                       for e, i, j in advanced_pairs)
# > 10775   advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#   10776   advanced_axes_are_contiguous = bool(np.all(np.diff(idx_advanced_axes) == 1))
#   10778 x_axis = 0  # Current axis in x.
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:10773, in <genexpr>(.0)
#   10769 advanced_pairs = (
#   10770   (asarray(e), i, j) for j, (i, e) in enumerate(idx_no_nones)
#   10771   if isscalar(e) or isinstance(e, (Sequence, Array, np.ndarray)))
#   10772 if normalize_indices:
# > 10773   advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#   10774                     for e, i, j in advanced_pairs)
#   10775 advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#   10776 advanced_axes_are_contiguous = bool(np.all(np.diff(idx_advanced_axes) == 1))
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:10771, in <genexpr>(.0)
#   10767 if _is_advanced_int_indexer(idx):
#   10768   idx_no_nones = [(i, d) for i, d in enumerate(idx) if d is not None]
#   10769   advanced_pairs = (
#   10770     (asarray(e), i, j) for j, (i, e) in enumerate(idx_no_nones)
# > 10771     if isscalar(e) or isinstance(e, (Sequence, Array, np.ndarray)))
#   10772   if normalize_indices:
#   10773     advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#   10774                       for e, i, j in advanced_pairs)
#
# File <frozen abc>:119, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:
