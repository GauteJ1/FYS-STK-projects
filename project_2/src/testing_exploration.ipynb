# %%
from exploration import Exploration

# %%
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "Adagrad", "RMSprop"]
layer_sizes = [4,8]
num_hidden_layers = [2,4]
learning_rates = [0.1, 0.01, 0.001, 0.0001]
batch_sizes_cont = [1000,3000]
batch_sizes_disc = [100,200]
activation_functions = ["ReLU","sigmoid"]

# %%
"""
optimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "Adagrad", "RMSprop"]
layer_sizes = [4,8,16]
num_hidden_layers = [2,3,4]
learning_rates = [0.1, 0.01, 0.001, 0.0001]
batch_sizes_cont = [1000, 3000, 5000]
batch_sizes_disc = [100, 200, 300]
activation_functions = ["ReLU", "leaky_ReLU", "sigmoid","identity"]
"""
# Out:
# '\noptimizers = ["Constant", "Momentum", "Adam", "Adagrad_Momentum", "Adagrad", "RMSprop"]\nlayer_sizes = [4,8,16]\nnum_hidden_layers = [2,3,4]\nlearning_rates = [0.1, 0.01, 0.001, 0.0001]\nbatch_sizes_cont = [1000, 3000, 5000]\nbatch_sizes_disc = [100, 200, 300]\nactivation_functions = ["ReLU", "leaky_ReLU", "sigmoid","identity"]\n'

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
exploration2.do_all(print_into=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Best optimizer: Momentum
# Best structure: [30, 8, 4, 1]
# Best activation functions: ['ReLU', 'ReLU', 'sigmoid']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
# ----> 2 exploration2.do_all(print_into=True)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:339, in Exploration.do_all(self, print_into)
#     337 self.find_structure()
#     338 self.find_activation_functions()
# --> 339 self.grid_search_for_optimizer()
#     340 self.make_best()
#     341 self.plot_best()
#
# ...

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
exploration1.do_all(print_into=True)
# Out:
# Best optimizer: Adagrad
# Best structure: [2, 4, 4, 1]
# Best activation functions: ['ReLU', 'sigmoid', 'identity']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
# ----> 2 exploration1.do_all(print_into=True)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:339, in Exploration.do_all(self, print_into)
#     337 self.find_structure()
#     338 self.find_activation_functions()
# --> 339 self.grid_search_for_optimizer()
#     340 self.make_best()
#     341 self.plot_best()
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:282, in Exploration.grid_search_for_optimizer(self)
#     280 best = {}
#     281 for optim, accuracy in all_acc.items():
# ...
