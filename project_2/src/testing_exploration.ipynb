# %%
from exploration import Exploration

# %%
optimizers = ["Constant"]#["Constant", "Momentum", "Adam", "Adagrad_Momentum", "RMSprop", "Adagrad"]
layer_sizes = [4,8]
num_hidden_layers = [2,3,4]
learning_rates = [0.1, 0.01,0.001, 0.0001]
batch_sizes_cont = [1000, 3000, 5000]
batch_sizes_disc = [100, 200, 300]
activation_functions = ["ReLU", "leaky_ReLU", "sigmoid"]

# %%
# smaller set of things to check for testing the code
"""
optimizers = ["Constant", "Momentum", "RMSprop"]
layer_sizes = [4,8]
num_hidden_layers = [2,4]
learning_rates = [0.01,0.001]
batch_sizes_cont = [1000, 5000]
batch_sizes_disc = [100, 300, 500]
activation_functions = ["ReLU", "sigmoid"]
"""
print()

# %%
exploration2 = Exploration("classification", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_disc, activation_functions)
exploration2.do_all(print_into=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# Best optimizer: RMSprop
# for RMSprop: 1.0053329467773438
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['ReLU', 'sigmoid', 'sigmoid']
# 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# Best optimizer: RMSprop
# Best structure: [30, 4, 8, 1]
# Best activation functions: ['ReLU', 'sigmoid', 'sigmoid']
# Best learning rate and batch size: (0.0001, 100)
# Final f1 socre: 0.0

# %%
exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
exploration1.do_all(print_into=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 exploration1 = Exploration("continuous", optimizers, layer_sizes, num_hidden_layers, learning_rates, batch_sizes_cont, activation_functions)
# ----> 2 exploration1.do_all(print_into=True)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:288, in Exploration.do_all(self, print_into)
#     286 self.print_info = print_into
#     287 self.generate_data()
# --> 288 self.find_ok_optimizer()
#     289 self.find_structure()
#     290 self.find_activation_functions()
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/exploration.py:138, in Exploration.find_ok_optimizer(self)
#     136 for optim in self.optimizers:
#     137     model = NeuralNetwork(network_shape, self.intermediary_activation_funcs, self.cost_function, self.type_model, optim)
# --> 138     model.train_network(self.inputs, self.targets, self.intermediary_epochs, self.intermediary_lr, self.intermediary_batch_size)
#     139     test_loss.append(model.test_loss)
#     140     test_accuracy.append(model.test_accuracy)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:176, in NeuralNetwork.train_network(self, inputs, targets, epochs, learning_rate, batch_size)
#     173 batch_inputs = train_inputs[batch_index:batch_index + 1]
#     174 batch_targets = train_targets[batch_index:batch_index + 1]
# --> 176 layers_grad = self.gradient(batch_inputs, batch_targets)
#     178 for idx, ((W, b), (W_g, b_g)) in enumerate(zip(self.layers, layers_grad)):
#     179     W_updated = self.update_beta(W, W_g, param_type="weights")
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_2/src/neural_network.py:238, in NeuralNetwork.jaxgrad_gradient(self, inputs, targets)
#     235     predictions = jax_grad_predict(layers, inputs)
#     236     return self.cost_fun(predictions, targets)
# --> 238 gradients = grad(jax_grad_cost, argnums=0)(self.layers, inputs, targets)
#     240 clipped_gradients = [(jnp.clip(W_grad, -1e12, 1e12), jnp.clip(b_grad, -1e12, 1e12)) for W_grad, b_grad in gradients]
#     242 return clipped_gradients
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:468, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     466 _check_scalar(ans)
#     467 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 468 g = vjp_py(lax_internal._one(ans))
#     469 g = g[0] if isinstance(argnums, int) else g
#     470 if not has_aux:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/api.py:1886, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    1879   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    1880       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    1881     raise ValueError(
#    1882         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    1883         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    1884         f"because the corresponding output of the function {name} had JAX type "
#    1885         f"{aval.str_short()}")
# -> 1886 ans = fun(*args)
#    1887 return tree_unflatten(out_tree, ans)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:149, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     147 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     148 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 149 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     150 return map(instantiate_zeros, arg_cts)
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:240, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     237   cts_out = reducing_transposes[eqn.primitive](
#     238       cts_in, *invals, **eqn.params)
#     239 else:
# --> 240   cts_out = get_primitive_transpose(eqn.primitive)(
#     241       cts_in, *invals, **eqn.params)
#     242 cts_out = [Zero(v.aval) for v in eqn.invars] if cts_out is Zero else cts_out
#     243 # FIXME: Some invars correspond to primals!
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/lax/lax.py:2624, in _mul_transpose(ct, x, y)
#    2623 def _mul_transpose(ct, x, y):
# -> 2624   assert ad.is_undefined_primal(x) ^ ad.is_undefined_primal(y)
#    2625   if ad.is_undefined_primal(x):
#    2626     if type(ct) is ad_util.Zero:
#
# File ~/anaconda3/envs/fysstk/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:262, in is_undefined_primal(x)
#     259   def __repr__(self):
#     260     return f'UndefinedPrimal({self.aval})'
# --> 262 def is_undefined_primal(x):
#     263   return type(x) is UndefinedPrimal
#     265 register_pytree_node(UndefinedPrimal,
#     266                      lambda z: ((), z.aval),
#     267                      lambda aval, _: UndefinedPrimal(aval))
#
# KeyboardInterrupt:
