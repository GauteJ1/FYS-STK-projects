# %%
from plotting import Plotting

plots = Plotting(data_points=41, data="Franke_Noise", seed=67)

# %%
plots.plot_OLS(y_axis="MSE", max_deg=11)

# %%
plots.plot_OLS(y_axis="R2")

# %%
plots.plot_betas("OLS", max_deg=12)
# Out:
# 1 [-0.00357556 -0.00315991]
# 2 [-0.02705674 -0.0226217   0.00148366  0.00172581  0.00107992]
# 3 [-0.10253803 -0.08216128  0.0126429   0.01471406  0.00863845 -0.00050749
#  -0.00071    -0.00058828 -0.00030764]
# 4 [-2.62716931e-01 -2.06298161e-01  5.30602577e-02  6.35257581e-02
#   3.53161033e-02 -4.57925070e-03 -6.77752310e-03 -5.54530752e-03
#  -2.71713656e-03  1.43341918e-04  2.42827854e-04  2.42671555e-04
#   1.68755686e-04  7.84158636e-05]
# 5 [-5.16443911e-01 -4.07298061e-01  1.46777923e-01  1.86170360e-01
#   9.95415088e-02 -1.97850445e-02 -3.21557570e-02 -2.65056608e-02
#  -1.22465484e-02  1.27431850e-03  2.44347027e-03  2.53231175e-03
#   1.73124579e-03  7.50856393e-04 -3.15194768e-05 -6.86536010e-05
#  -8.29041884e-05 -6.97011736e-05 -4.33084670e-05 -1.82428047e-05]
# 6 [-8.28973878e-01 -6.71090518e-01  2.97262872e-01  4.18103662e-01
#   2.13643443e-01 -5.28892058e-02 -1.01269437e-01 -8.61587616e-02
#  -3.58784710e-02  4.94130477e-03  1.19242439e-02  1.32381796e-02
# ...

# %%
plots.plot_betas(model="Ridge", lmbda=0.5)

# %%
plots.plot_betas(model="Lasso", lmbda=0.5)

# %%
plots.plot_lambda(model = "Ridge", y_axis="MSE")

# %%
plots.plot_lambda(model = "Ridge", y_axis="R2")

# %%
plots.plot_lambda(model = "Lasso", y_axis="MSE")

# %%
plots.plot_lambda(model = "Lasso", y_axis="R2")

# %%
plots.plot_all_betas(lmbda=0.1)

# %%
plots.plot_betas_lambda("Ridge")

# %%
plots.plot_betas_lambda("Lasso")
