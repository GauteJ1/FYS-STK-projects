# %%
from plotting import Plotting
import matplotlib.pyplot as plt

plots = Plotting(data_points=41, data="Franke_Noise", seed=42)
plots_terrain = Plotting(data_points=41, data="Terrain", seed=42)

# %%
plots.plot_MSE_R2(y_axis="MSE", max_deg=11)
plt.savefig("../figures/data/OLS_MSE_Franke_Noise.pdf")

# %%
plots_terrain.plot_MSE_R2(y_axis="MSE", max_deg=11)
plt.savefig("../figures/data/OLS_MSE_Terrain.pdf")

# %%
plots.plot_MSE_R2(y_axis="R2")
plt.savefig("../figures/data/OLS_R2_Franke_Noise.pdf")

# %%
plots_terrain.plot_MSE_R2(y_axis="R2")
plt.savefig("../figures/data/OLS_R2_Terrain.pdf")

# %%
plots.plot_MSE_R2(y_axis="MSE", model_name="Ridge", lmbda=1e-5, max_deg=11)
plt.savefig("../figures/data/Ridge_MSE_Franke_Noise.pdf")

# %%
plots_terrain.plot_MSE_R2(y_axis="MSE", model_name="Ridge", lmbda=1e-5, max_deg=11)
plt.savefig("../figures/data/Ridge_MSE_Terrain.pdf")

# %%
plots.plot_lambda(model_name = "Ridge", y_axis="MSE", deg=10)
plt.savefig("../figures/data/Ridge_lambda_MSE_Franke_Noise.pdf")

# %%
plots_terrain.plot_lambda(model_name = "Ridge", y_axis="MSE", deg=10)
plt.savefig("../figures/data/Ridge_lambda_MSE_Terrain.pdf")

# %%
plots.plot_lambda(model_name = "Ridge", y_axis="R2")
plt.savefig("../figures/data/Ridge_lambda_R2_Franke_Noise.pdf")

# %%
plots_terrain.plot_lambda(model_name = "Ridge", y_axis="R2")
plt.savefig("../figures/data/Ridge_lambda_R2_Terrain.pdf")

# %%
plots.plot_lambda(model_name = "Lasso", y_axis="MSE", deg=5)
plt.savefig("../figures/data/Lasso_lambda_MSE_Franke_Noise.pdf")
# Out:
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.618e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.560e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.441e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.384e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.329e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.275e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.221e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.517e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.018e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.389e+00, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.114e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.298e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.229e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.613e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(

# %%
plots_terrain.plot_lambda(model_name = "Lasso", y_axis="MSE", deg=5)
plt.savefig("../figures/data/Lasso_lambda_MSE_Terrain.pdf")
# Out:
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.057e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.057e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.056e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.048e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.035e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.029e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.022e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.016e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.002e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.957e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.274e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.563e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.826e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.115e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.623e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.242e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.776e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.382e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.035e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.204e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.222e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.239e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.674e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.790e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 plots_terrain.plot_lambda(model_name = "Lasso", y_axis="MSE", deg=5)
# ----> 2 plt.savefig("../figures/data/Lasso_lambda_MSE_Terrain.pdf")
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backends/backend_pdf.py:2799, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2794 file.newPage(width, height)
#    2795 renderer = MixedModeRenderer(
#    2796     self.figure, width, height, dpi,
#    2797     RendererPdf(file, dpi, height, width),
#    2798     bbox_inches_restore=bbox_inches_restore)
# -> 2799 self.figure.draw(renderer)
#    2800 renderer.finalize()
#    2801 if not isinstance(filename, PdfPages):
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:3036, in _AxesBase._update_title_position(self, renderer)
#    3033 bb = None
#    3034 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    3035         or ax.xaxis.get_label_position() == 'top'):
# -> 3036     bb = ax.xaxis.get_tightbbox(renderer)
#    3037 if bb is None:
#    3038     if 'outline' in ax.spines:
#    3039         # Special case for colorbars:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:2413, in XAxis._update_label_position(self, renderer)
#    2409     return
#    2411 # get bounding boxes for this axis and any siblings
#    2412 # that have been set by `fig.align_xlabels()`
# -> 2413 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2415 x, y = self.label.get_position()
#    2416 if self.label_position == 'bottom':
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backends/_backend_pdf_ps.py:114, in RendererPDFPSBase.get_text_width_height_descent(self, s, prop, ismath)
#     112     return super().get_text_width_height_descent(s, prop, ismath)
#     113 elif ismath:
# --> 114     parse = self._text2path.mathtext_parser.parse(s, 72, prop)
#     115     return parse.width, parse.height, parse.depth
#     116 elif mpl.rcParams[self._use_afm_rc_name]:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/mathtext.py:79, in MathTextParser.parse(self, s, dpi, prop, antialiased)
#      77 prop = prop.copy() if prop is not None else None
#      78 antialiased = mpl._val_or_rc(antialiased, 'text.antialiased')
# ---> 79 return self._parse_cached(s, dpi, prop, antialiased)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/mathtext.py:100, in MathTextParser._parse_cached(self, s, dpi, prop, antialiased)
#      97 if self._parser is None:  # Cache the parser globally.
#      98     self.__class__._parser = _mathtext.Parser()
# --> 100 box = self._parser.parse(s, fontset, fontsize, dpi)
#     101 output = _mathtext.ship(box)
#     102 if self._output_type == "vector":
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/_mathtext.py:2170, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2168 self._em_width_cache: dict[tuple[str, float, float], float] = {}
#    2169 try:
# -> 2170     result = self._expression.parseString(s)
#    2171 except ParseBaseException as err:
#    2172     # explain becomes a plain method on pyparsing 3 (err.explain(0)).
#    2173     raise ValueError("\n" + ParseException.explain(err, 0)) from None
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/util.py:256, in replaced_by_pep8.<locals>._inner(self, *args, **kwargs)
#     251 @wraps(fn)
#     252 def _inner(self, *args, **kwargs):
#     253     # warnings.warn(
#     254     #     f"Deprecated - use {fn.__name__}", DeprecationWarning, stacklevel=2
#     255     # )
# --> 256     return fn(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:1190, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1188     instring = instring.expandtabs()
#    1189 try:
# -> 1190     loc, tokens = self._parse(instring, 0)
#    1191     if parseAll:
#    1192         loc = self.preParse(instring, loc)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4019, in And.parseImpl(self, instring, loc, doActions)
#    4015             raise ParseSyntaxException(
#    4016                 instring, len(instring), self.errmsg, self
#    4017             )
#    4018     else:
# -> 4019         loc, exprtokens = e._parse(instring, loc, doActions)
#    4020     resultlist += exprtokens
#    4021 return loc, resultlist
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5042, in ZeroOrMore.parseImpl(self, instring, loc, doActions)
#    5040 def parseImpl(self, instring, loc, doActions=True):
#    5041     try:
# -> 5042         return super().parseImpl(instring, loc, doActions)
#    5043     except (ParseException, IndexError):
#    5044         return loc, ParseResults([], name=self.resultsName)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4941, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4939 if check_ender:
#    4940     try_not_ender(instring, loc)
# -> 4941 loc, tokens = self_expr_parse(instring, loc, doActions)
#    4942 try:
#    4943     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:3997, in And.parseImpl(self, instring, loc, doActions)
#    3994 def parseImpl(self, instring, loc, doActions=True):
#    3995     # pass False as callPreParse arg to _parse for first element, since we already
#    3996     # pre-parsed the string as part of our And pre-parsing
# -> 3997     loc, resultlist = self.exprs[0]._parse(
#    3998         instring, loc, doActions, callPreParse=False
#    3999     )
#    4000     errorStop = False
#    4001     for e in self.exprs[1:]:
#    4002         # if isinstance(e, And._ErrorStop):
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:891, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     889 for fn in self.parseAction:
#     890     try:
# --> 891         tokens = fn(instring, tokens_start, ret_tokens)  # type: ignore [call-arg, arg-type]
#     892     except IndexError as parse_action_exc:
#     893         exc = ParseException("exception raised in parse action")
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:293, in _trim_arity.<locals>.wrapper(*args)
#     291 while 1:
#     292     try:
# --> 293         ret = func(*args[limit:])
#     294         found_arity = True
#     295         return ret
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/_mathtext.py:2197, in Parser.math_string(self, toks)
#    2196 def math_string(self, toks: ParseResults) -> ParseResults:
# -> 2197     return self._math_expression.parseString(toks[0][1:-1], parseAll=True)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/util.py:256, in replaced_by_pep8.<locals>._inner(self, *args, **kwargs)
#     251 @wraps(fn)
#     252 def _inner(self, *args, **kwargs):
#     253     # warnings.warn(
#     254     #     f"Deprecated - use {fn.__name__}", DeprecationWarning, stacklevel=2
#     255     # )
# --> 256     return fn(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:1190, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1188     instring = instring.expandtabs()
#    1189 try:
# -> 1190     loc, tokens = self._parse(instring, 0)
#    1191     if parseAll:
#    1192         loc = self.preParse(instring, loc)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4941, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4939 if check_ender:
#    4940     try_not_ender(instring, loc)
# -> 4941 loc, tokens = self_expr_parse(instring, loc, doActions)
#    4942 try:
#    4943     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5469, in Forward.parseImpl(self, instring, loc, doActions)
#    5464     warnings.warn(
#    5465         "Forward expression was never assigned a value, will not parse any input",
#    5466         stacklevel=stacklevel,
#    5467     )
#    5468 if not ParserElement._left_recursion_enabled:
# -> 5469     return super().parseImpl(instring, loc, doActions)
#    5470 # ## Bounded Recursion algorithm ##
#    5471 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5472 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5487 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5488 # recursion level is acceptable.
#    5489 with ParserElement.recursion_lock:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4517, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4514     raise ParseException(instring, loc, "No expression defined", self)
#    4516 try:
# -> 4517     return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4518 except ParseBaseException as pbe:
#    4519     if not isinstance(self, Forward) or self.customName is not None:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:3997, in And.parseImpl(self, instring, loc, doActions)
#    3994 def parseImpl(self, instring, loc, doActions=True):
#    3995     # pass False as callPreParse arg to _parse for first element, since we already
#    3996     # pre-parsed the string as part of our And pre-parsing
# -> 3997     loc, resultlist = self.exprs[0]._parse(
#    3998         instring, loc, doActions, callPreParse=False
#    3999     )
#    4000     errorStop = False
#    4001     for e in self.exprs[1:]:
#    4002         # if isinstance(e, And._ErrorStop):
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5176, in Opt.parseImpl(self, instring, loc, doActions)
#    5174 self_expr = self.expr
#    5175 try:
# -> 5176     loc, tokens = self_expr._parse(instring, loc, doActions, callPreParse=False)
#    5177 except (ParseException, IndexError):
#    5178     default_value = self.defaultValue
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5469, in Forward.parseImpl(self, instring, loc, doActions)
#    5464     warnings.warn(
#    5465         "Forward expression was never assigned a value, will not parse any input",
#    5466         stacklevel=stacklevel,
#    5467     )
#    5468 if not ParserElement._left_recursion_enabled:
# -> 5469     return super().parseImpl(instring, loc, doActions)
#    5470 # ## Bounded Recursion algorithm ##
#    5471 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5472 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5487 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5488 # recursion level is acceptable.
#    5489 with ParserElement.recursion_lock:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4517, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4514     raise ParseException(instring, loc, "No expression defined", self)
#    4516 try:
# -> 4517     return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4518 except ParseBaseException as pbe:
#    4519     if not isinstance(self, Forward) or self.customName is not None:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4019, in And.parseImpl(self, instring, loc, doActions)
#    4015             raise ParseSyntaxException(
#    4016                 instring, len(instring), self.errmsg, self
#    4017             )
#    4018     else:
# -> 4019         loc, exprtokens = e._parse(instring, loc, doActions)
#    4020     resultlist += exprtokens
#    4021 return loc, resultlist
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5042, in ZeroOrMore.parseImpl(self, instring, loc, doActions)
#    5040 def parseImpl(self, instring, loc, doActions=True):
#    5041     try:
# -> 5042         return super().parseImpl(instring, loc, doActions)
#    5043     except (ParseException, IndexError):
#    5044         return loc, ParseResults([], name=self.resultsName)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4951, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4949         else:
#    4950             preloc = loc
# -> 4951         loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4952         tokens += tmptokens
#    4953 except (ParseException, IndexError):
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5469, in Forward.parseImpl(self, instring, loc, doActions)
#    5464     warnings.warn(
#    5465         "Forward expression was never assigned a value, will not parse any input",
#    5466         stacklevel=stacklevel,
#    5467     )
#    5468 if not ParserElement._left_recursion_enabled:
# -> 5469     return super().parseImpl(instring, loc, doActions)
#    5470 # ## Bounded Recursion algorithm ##
#    5471 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5472 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5487 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5488 # recursion level is acceptable.
#    5489 with ParserElement.recursion_lock:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4517, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4514     raise ParseException(instring, loc, "No expression defined", self)
#    4516 try:
# -> 4517     return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4518 except ParseBaseException as pbe:
#    4519     if not isinstance(self, Forward) or self.customName is not None:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4019, in And.parseImpl(self, instring, loc, doActions)
#    4015             raise ParseSyntaxException(
#    4016                 instring, len(instring), self.errmsg, self
#    4017             )
#    4018     else:
# -> 4019         loc, exprtokens = e._parse(instring, loc, doActions)
#    4020     resultlist += exprtokens
#    4021 return loc, resultlist
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4941, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4939 if check_ender:
#    4940     try_not_ender(instring, loc)
# -> 4941 loc, tokens = self_expr_parse(instring, loc, doActions)
#    4942 try:
#    4943     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4008, in And.parseImpl(self, instring, loc, doActions)
#    4006 if errorStop:
#    4007     try:
# -> 4008         loc, exprtokens = e._parse(instring, loc, doActions)
#    4009     except ParseSyntaxException:
#    4010         raise
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5469, in Forward.parseImpl(self, instring, loc, doActions)
#    5464     warnings.warn(
#    5465         "Forward expression was never assigned a value, will not parse any input",
#    5466         stacklevel=stacklevel,
#    5467     )
#    5468 if not ParserElement._left_recursion_enabled:
# -> 5469     return super().parseImpl(instring, loc, doActions)
#    5470 # ## Bounded Recursion algorithm ##
#    5471 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5472 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5487 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5488 # recursion level is acceptable.
#    5489 with ParserElement.recursion_lock:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4517, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4514     raise ParseException(instring, loc, "No expression defined", self)
#    4516 try:
# -> 4517     return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4518 except ParseBaseException as pbe:
#    4519     if not isinstance(self, Forward) or self.customName is not None:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4019, in And.parseImpl(self, instring, loc, doActions)
#    4015             raise ParseSyntaxException(
#    4016                 instring, len(instring), self.errmsg, self
#    4017             )
#    4018     else:
# -> 4019         loc, exprtokens = e._parse(instring, loc, doActions)
#    4020     resultlist += exprtokens
#    4021 return loc, resultlist
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5042, in ZeroOrMore.parseImpl(self, instring, loc, doActions)
#    5040 def parseImpl(self, instring, loc, doActions=True):
#    5041     try:
# -> 5042         return super().parseImpl(instring, loc, doActions)
#    5043     except (ParseException, IndexError):
#    5044         return loc, ParseResults([], name=self.resultsName)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4951, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4949         else:
#    4950             preloc = loc
# -> 4951         loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4952         tokens += tmptokens
#    4953 except (ParseException, IndexError):
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:5469, in Forward.parseImpl(self, instring, loc, doActions)
#    5464     warnings.warn(
#    5465         "Forward expression was never assigned a value, will not parse any input",
#    5466         stacklevel=stacklevel,
#    5467     )
#    5468 if not ParserElement._left_recursion_enabled:
# -> 5469     return super().parseImpl(instring, loc, doActions)
#    5470 # ## Bounded Recursion algorithm ##
#    5471 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5472 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5487 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5488 # recursion level is acceptable.
#    5489 with ParserElement.recursion_lock:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4517, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4514     raise ParseException(instring, loc, "No expression defined", self)
#    4516 try:
# -> 4517     return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4518 except ParseBaseException as pbe:
#    4519     if not isinstance(self, Forward) or self.customName is not None:
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 974 (1 times), ParserElement._parseNoCache at line 852 (1 times)]
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:4248, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4246 for e in self.exprs:
#    4247     try:
# -> 4248         return e._parse(instring, loc, doActions)
#    4249     except ParseFatalException as pfe:
#    4250         pfe.__traceback__ = None
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:852, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     850 if self.mayIndexError or pre_loc >= len_instring:
#     851     try:
# --> 852         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     853     except IndexError:
#     854         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:3997, in And.parseImpl(self, instring, loc, doActions)
#    3994 def parseImpl(self, instring, loc, doActions=True):
#    3995     # pass False as callPreParse arg to _parse for first element, since we already
#    3996     # pre-parsed the string as part of our And pre-parsing
# -> 3997     loc, resultlist = self.exprs[0]._parse(
#    3998         instring, loc, doActions, callPreParse=False
#    3999     )
#    4000     errorStop = False
#    4001     for e in self.exprs[1:]:
#    4002         # if isinstance(e, And._ErrorStop):
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:974, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     972 ParserElement.packrat_cache_stats[MISS] += 1
#     973 try:
# --> 974     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     975 except ParseBaseException as pe:
#     976     # cache a copy of the exception, without the traceback
#     977     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~/.local/lib/python3.12/site-packages/pyparsing/core.py:860, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     856         loc, tokens = self.parseImpl(instring, pre_loc, doActions)
#     858 tokens = self.postParse(instring, loc, tokens)
# --> 860 ret_tokens = ParseResults(
#     861     tokens, self.resultsName, asList=self.saveAsList, modal=self.modalResults
#     862 )
#     863 if self.parseAction and (doActions or self.callDuringTry):
#     864     if debugging:
#
# KeyboardInterrupt:

# %%
plots.plot_lambda(model_name = "Lasso", y_axis="R2")
plt.savefig("../figures/data/Lasso_lambda_R2_Franke_Noise.pdf")

# %%
plots_terrain.plot_lambda(model_name = "Lasso", y_axis="R2")
plt.savefig("../figures/data/Lasso_lambda_R2_Terrain.pdf")

# %%
plots.plot_all_betas(ridge_lambda=0.1, lasso_lambda=0.0001)
plt.savefig("../figures/data/OLS_Ridge_Lasso_Betas_Franke_Noise.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.835e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.275e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(

# %%
plots_terrain.plot_all_betas(ridge_lambda=0.1, lasso_lambda=0.0001)
plt.savefig("../figures/data/OLS_Ridge_Lasso_Betas_Terrain.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.056e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(

# %%
plots.plot_betas_lambda("Ridge")
plt.savefig("../figures/data/Ridge_Betas_lambda_Franke_Noise_const_deg.pdf")

# %%
plots_terrain.plot_betas_lambda("Ridge")
plt.savefig("../figures/data/Ridge_Betas_lambda_Terrain_const_deg.pdf")

# %%
plots.plot_betas_lambda("Lasso")
plt.savefig("../figures/data/Lasso_Betas_lambda_Franke_Noise_const_deg.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.418e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.669e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.840e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.099e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.434e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.835e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.166e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e+01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.994e+00, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.414e+00, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.574e+00, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.494e+00, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.481e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.634e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.423e-01, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(

# %%
plots_terrain.plot_betas_lambda("Lasso")
plt.savefig("../figures/data/Lasso_Betas_lambda_Terrain_const_deg.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.057e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.057e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.056e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.048e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.036e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.017e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.011e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e+09, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.985e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.385e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.810e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.262e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.740e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.244e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.774e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.330e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.912e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.517e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.710e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+08, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.646e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.268e+07, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.904e+06, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.120e+06, tolerance: 2.123e+05
#   model = cd_fast.enet_coordinate_descent(
