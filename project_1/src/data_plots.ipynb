# %%
from data_gen import FrankeDataGen, TerrainDataGen

data = FrankeDataGen(data_points = 201)

data.plot_data()

# %%
from data_gen import TerrainDataGen

data = TerrainDataGen(step_size= 0.01)

# Not implemented yet
data.plot_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       3 data = TerrainDataGen(step_size= 0.01)
#       5 # Not implemented yet
# ----> 6 data.plot_data()
#
# File ~/Documents/FYS-STK-projects/project_1/src/data_gen.py:88, in TerrainDataGen.plot_data(self)
#      87 def plot_data(self) -> None:
# ---> 88     z = self.z
#      89     z_lim = (-10, 10)  # TODO: set terrain data z_lim if needed
#      90     super().plot_data(z, z_lim, "Terrain")
#
# AttributeError: 'TerrainDataGen' object has no attribute 'z'
