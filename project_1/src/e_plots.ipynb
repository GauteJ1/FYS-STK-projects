# %%
from plotting import Plotting
import matplotlib.pyplot as plt
import json

plots = Plotting(data_points=41, data="Franke_Noise", seed=12)
plots_terrain = Plotting(data_points=400, data="Terrain", seed=12)

# %%
#loading paramters fiund from grid search

with open('best_params.json', 'r') as f: 
    best_params = json.load(f)

best_lambda_lasso = best_params["best_params_lasso_franke"]["best_lambda"]
best_deg_lasso = best_params["best_params_lasso_franke"]["best_degree"]

best_lambda_ridge = best_params["best_params_ridge_franke"]["best_lambda"]
best_deg_ridge = best_params["best_params_ridge_franke"]["best_degree"]

best_lambda_lasso_terrain = best_params["best_params_lasso_terrain"]["best_lambda"]
best_deg_lasso_terrain = best_params["best_params_lasso_terrain"]["best_degree"]

best_lambda_ridge_terrain = best_params["best_params_ridge_terrain"]["best_lambda"]
best_deg_ridge_terrain = best_params["best_params_ridge_terrain"]["best_degree"]

# %%
plots.plot_bootstrap_MSE_R2(max_deg = 10)
plt.savefig("../figures/data/OLS_MSE_Franke_Noise_bootstrap.pdf")

# %%
plots_terrain.plot_bootstrap_MSE_R2(max_deg = 11)
plt.savefig("../figures/data/OLS_MSE_Terrain_bootstrap.pdf")

# %%
plots.plot_bootstrap_MSE_R2(model_name="Ridge", lmbda=1e-5, max_deg = 10, n_samples=100)
plt.savefig("../figures/data/Ridge_MSE_Franke_Noise_bootstrap.pdf")

# %%
plots_terrain.plot_bootstrap_MSE_R2(model_name="Ridge", lmbda=1e-5, max_deg = 10, n_samples=100)
plt.savefig("../figures/data/Ridge_MSE_Terrain_bootstrap.pdf")

# %%
plots.plot_bootstrap_bias_var(max_deg=10)
plt.savefig("../figures/data/bias_var_Franke_Noise_bootstrap.pdf")

# %%
plots_terrain.plot_bootstrap_bias_var(max_deg=10)
plt.savefig("../figures/data/bias_var_Terrain_bootstrap.pdf")

# %%
plots.plot_cross_val_MSE(kfolds=5, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Franke_Noise_CV_k5.pdf")

# %%
plots_terrain.plot_cross_val_MSE(kfolds=5, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Terrain_CV_k5.pdf")

# %%
plots.plot_cross_val_MSE(kfolds=7, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Franke_Noise_CV_k7.pdf")

# %%
plots_terrain.plot_cross_val_MSE(kfolds=7, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Terrain_CV_k7.pdf")

# %%
plots.plot_cross_val_MSE(kfolds=10, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Franke_Noise_CV_k10.pdf")

# %%
plots_terrain.plot_cross_val_MSE(kfolds=10, max_deg=10)
plt.savefig("../figures/data/OLS_MSE_Terrain_CV_k10.pdf")

# %%
plots_terrain.plot_all_boot(ridge_lambda=best_lambda_ridge_terrain, lasso_lambda=best_lambda_lasso_terrain, max_degree=12, n_samples=10)
plt.savefig("../figures/data/All_bootstrap_Terrain.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+11, tolerance: 2.030e+07
#   model = cd_fast.enet_coordinate_descent(
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+11, tolerance: 2.033e+07
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
plots_terrain.plot_all_cv(ridge_lambda=1e-5, lasso_lambda=1e-5, max_degree=10, k_folds=10)
plt.savefig("../figures/data/All_Terrain_CV_k10.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+11, tolerance: 2.286e+07
#   model = cd_fast.enet_coordinate_descent(
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10548cf20>>
# Traceback (most recent call last):
#   File "/Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ...

# %%
plots_terrain.plot_all_ols(max_degree=10)
plt.savefig("../figures/data/All_Terrain_OLS.pdf")
# Out:
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/base.py:1473: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/miamerlid/anaconda3/envs/fysstk/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# ...
