# %%
from plotting import Plotting
import matplotlib.pyplot as plt

plots = Plotting(data_points=31, real_data=False)

# %%
plots.plot_bias_var_bootstrap(max_deg=11)
plt.savefig('../images/bias_var_bootstrap.png')

# %%
plots.plot_mse_bootstrap(max_deg = 11)

# %%
plots.plot_mse_cv(kfolds=5, max_deg=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plots.plot_mse_cv(kfolds=5, max_deg=10)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_1/src/plotting.py:224, in Plotting.plot_mse_cv(self, kfolds, min_deg, max_deg, model, lmbda)
#     222 if model == "OLS":
#     223     model = OLSModel(handler)
# --> 224     degs, errors = model.cv_mult_degs(
#     225         min_deg=min_deg, max_deg=max_deg, kfolds=kfolds
#     226     )
#     227 elif model == "Ridge":
#     228     model = RidgeModel(handler)
#
# File ~/Desktop/Master/FYS-STK4155/FYS-STK-projects/project_1/src/reg_models.py:154, in RegModel.cv_mult_degs(self, min_deg, max_deg, kfolds)
#     152 for deg in range(min_deg, max_deg + 1):
#     153     deg_list.append(deg)
# --> 154     err = self.cross_validation(deg, kfolds)
#     155     variance_list.append(var)
# ...
