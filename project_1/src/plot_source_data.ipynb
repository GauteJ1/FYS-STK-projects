# %%
from data_gen import FrankeDataGen

data = FrankeDataGen(data_points = 41)

data.plot_data(save_path="../images/data/franke_func")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from data_gen import FrankeDataGen
#       3 data = FrankeDataGen(data_points = 41)
# ----> 5 data.plot_data(save_path="images/data/franke_func")
#
# File ~/Documents/FYS-STK-projects/project_1/src/data_gen.py:85, in FrankeDataGen.plot_data(self, save_path)
#      83     super().plot_data(z, z_lim, "Franke Function with noise", save_path)
#      84 else:
# ---> 85     super().plot_data(z, z_lim, "Franke Function", save_path)
#
# File ~/Documents/FYS-STK-projects/project_1/src/data_gen.py:47, in DataGen.plot_data(self, z, z_lim, title, save_path)
#      45 fig.tight_layout()
#      46 if save_path != "None":
# ---> 47     plt.savefig(save_path)
#      48 plt.show()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
# ...

# %%
data = FrankeDataGen(data_points = 41, noise=True)

data.plot_data(save_path="../images/data/franke_func_noise")

# %%
from data_gen import TerrainDataGen

data = TerrainDataGen(step_size= 0.01)

# Not implemented yet
data.plot_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from data_gen import TerrainDataGen
# ----> 3 data = TerrainDataGen(step_size= 0.01)
#       5 # Not implemented yet
#       6 data.plot_data()
#
# TypeError: TerrainDataGen.__init__() got an unexpected keyword argument 'step_size'
