# %%
f = lambda x: x**11 - x**2 - 2 * x + 4

# %%
coeffs = [
    [-2.40023659],
    [-3.08660947, 0.66264797],
    [-0.35284328, -6.83393243, 5.09812412],
    [-3.41178486, 7.84036645, -17.85578086, 11.35989508],
    [-1.2402171, -8.39878868, 25.52633396, -36.64155975, 18.75099812],
    [-2.26696585, 3.07282543, -21.89604706, 53.23218683, -60.34411441, 26.19794689],
    [
        -1.94437757,
        -2.3535473,
        10.7814572,
        -39.78530857,
        75.48157851,
        -72.19255694,
        28.01259035,
    ],
    [
        -2.01445221,
        -0.53832067,
        -4.68118307,
        22.59431674,
        -59.54899368,
        88.90226809,
        -71.78177719,
        25.06810894,
    ],
    [
        -1.99717053,
        -1.09880453,
        1.18499658,
        -7.02759048,
        23.85756014,
        -49.13962835,
        61.72843234,
        -44.76930853,
        15.26168178,
    ],
    [
        -1.97930761,
        -1.04185547,
        -0.08047599,
        0.8947615,
        -3.9621637,
        10.52806383,
        -18.07750242,
        20.21281393,
        -14.22317705,
        5.71504093,
    ],
    [
        -75.83484033,
        169.01870802,
        -91.67443723,
        -149.48629618,
        249.164756,
        -125.54842353,
        3.62310469,
        11.62609184,
        -2.34864509,
        0.69477537,
        0.76389892,
    ],
    [
        2.79101327e00,
        -1.33514850e01,
        5.45525183e01,
        -1.29692995e02,
        1.46350955e02,
        -8.12266145e01,
        1.67603242e01,
        2.11304109e00,
        -6.40359953e-01,
        -1.71931610e-01,
        8.81024044e-01,
        5.52956010e-02,
    ],
]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 1, 201)

y = np.sum([x**(i+1) * a for (i, a) in enumerate(coeffs[10])], axis=0)

plt.plot(x, f(x))
plt.plot(x, y)

# %%
degree = 11
x = np.linspace(0, 1, 21)
X = np.zeros((len(x), degree))
for i in range(degree):
    deg = i + 1
    X[:, i] = x ** deg

print(X)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [5.00000000e-02 2.50000000e-03 1.25000000e-04 6.25000000e-06
#   3.12500000e-07 1.56250000e-08 7.81250000e-10 3.90625000e-11
#   1.95312500e-12 9.76562500e-14 4.88281250e-15]
#  [1.00000000e-01 1.00000000e-02 1.00000000e-03 1.00000000e-04
#   1.00000000e-05 1.00000000e-06 1.00000000e-07 1.00000000e-08
#   1.00000000e-09 1.00000000e-10 1.00000000e-11]
#  [1.50000000e-01 2.25000000e-02 3.37500000e-03 5.06250000e-04
#   7.59375000e-05 1.13906250e-05 1.70859375e-06 2.56289063e-07
#   3.84433594e-08 5.76650391e-09 8.64975586e-10]
#  [2.00000000e-01 4.00000000e-02 8.00000000e-03 1.60000000e-03
#   3.20000000e-04 6.40000000e-05 1.28000000e-05 2.56000000e-06
#   5.12000000e-07 1.02400000e-07 2.04800000e-08]
#  [2.50000000e-01 6.25000000e-02 1.56250000e-02 3.90625000e-03
# ...
