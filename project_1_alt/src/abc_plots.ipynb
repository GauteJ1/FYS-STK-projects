# %%
from plotting import Plotting

plots = Plotting(data_points=41, data="Franke_Noise", seed=42)

# %%
plots.plot_MSE_R2(y_axis="MSE", max_deg=11)
# Out:
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)

# %%
plots.plot_MSE_R2(y_axis="R2")
# Out:
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)

# %%
plots.plot_MSE_R2(y_axis="MSE", model_name="Ridge", lmbda=1e-5, max_deg=11)
# Out:
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)

# %%
plots.plot_lambda(model_name = "Ridge", y_axis="MSE", deg=10)
# Out:
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ...

# %%
plots.plot_lambda(model_name = "Ridge", y_axis="R2")
# Out:
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ikke lasso (1344, 1)
# ikke lasso (337, 1)
# ...

# %%
plots.plot_lambda(model_name = "Lasso", y_axis="MSE", deg=5)
# Out:
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.618e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
plots.plot_lambda(model_name = "Lasso", y_axis="R2")
# Out:
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# lasso (337, 1)
# lasso (1344, 1)
# ...

# %%
plots.plot_all_betas(ridge_lambda=0.1, lasso_lambda=0.0001)

# %%
plots.plot_betas_lambda("Ridge")

# %%
plots.plot_betas_lambda("Lasso")
# Out:
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/gautejohannessen/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.418e+02, tolerance: 4.529e-02
#   model = cd_fast.enet_coordinate_descent(
# ...
